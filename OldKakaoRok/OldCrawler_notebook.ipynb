# %%
from glob import glob
import pandas as pd
csv_path = './*.csv'
csv_list = glob(csv_path)

# %%
csv_list
# Out:
# ['./matki_DB.csv']

# %%
raw_df = pd.read_csv(csv_list[0])
# Out:
# <ipython-input-4-9d48f952e6da>:1: DtypeWarning: Columns (14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_df = pd.read_csv(csv_list[0])

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214664 entries, 0 to 214663
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   region           214664 non-null  object
#  1   name             214664 non-null  object
#  2   addresse         214664 non-null  object
#  3   cat1             214664 non-null  object
#  4   cat2             214512 non-null  object
#  5   review_num       204853 non-null  float64
#  6   blog_review_num  214664 non-null  int64
#  7   score_min        214664 non-null  float64
#  8   likePoint        204217 non-null  object
#  9   likePointCnt     204217 non-null  object
#  10  rate             214664 non-null  float64
#  11  reviewerCnt      214664 non-null  object
#  12  reviewAt         214664 non-null  float64
#  13  reviews_date     214664 non-null  object
#  14  lon              214664 non-null  object
#  15  lat              214664 non-null  object
#  16  url              136139 non-null  object
#  17  open_time        101462 non-null  object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 29.5+ MB

# %%
raw_df = raw_df.dropna(subset=['url', 'reviewer_id'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raw_df = raw_df.dropna(subset=['url', 'reviewer_id'])
#
# File ~/miniforge3/envs/env_deepface/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/env_deepface/lib/python3.8/site-packages/pandas/core/frame.py:6558, in DataFrame.dropna(self, axis, how, thresh, subset, inplace)
#    6556     check = indices == -1
#    6557     if check.any():
# -> 6558         raise KeyError(np.array(subset)[check].tolist())
#    6559     agg_obj = self.take(indices, axis=agg_axis)
#    6561 if thresh is not no_default:
#
# KeyError: ['reviewer_id']

# %%
len(raw2)
# Out:
# 16498

# %%
raw3 = raw3.dropna(subset=['url', 'reviewer_id'])

# %%
all_df = pd.concat([raw1,raw2,raw3])

# %%
all_df = all_df.dropna(subset=['url', 'reviewer_id', 'reviewAt'])

# %%
all_df

# %%
all_df_set = set(all_df['region'].to_list())
all_df_set
# Out:
# {'광흥창역', '양재역', '역삼역', '합정', '홍대입구역'}

# %%
raw3[raw3['region'] == '망원']
# Out:
#        region             name                          addresse     cat1  \
# 115054     망원  망원동즉석우동전문돈까스 본점         서울 마포구 동교로 83 1층 (우)04018       한식
# 115055     망원  망원동즉석우동전문돈까스 본점         서울 마포구 동교로 83 1층 (우)04018       한식
# 115056     망원  망원동즉석우동전문돈까스 본점         서울 마포구 동교로 83 1층 (우)04018       한식
# 115057     망원  망원동즉석우동전문돈까스 본점         서울 마포구 동교로 83 1층 (우)04018       한식
# 115058     망원  망원동즉석우동전문돈까스 본점         서울 마포구 동교로 83 1층 (우)04018       한식
# ...       ...              ...                               ...      ...
# 130613     망원         카페밤비 2호점  서울 마포구 월드컵로21길 18 가동 1층 (우)04012  베이커리,카페
# 130614     망원         카페밤비 2호점  서울 마포구 월드컵로21길 18 가동 1층 (우)04012  베이커리,카페
# 130615     망원         카페밤비 2호점  서울 마포구 월드컵로21길 18 가동 1층 (우)04012  베이커리,카페
# 130616     망원         카페밤비 2호점  서울 마포구 월드컵로21길 18 가동 1층 (우)04012  베이커리,카페
# 130617     망원         카페밤비 2호점  서울 마포구 월드컵로21길 18 가동 1층 (우)04012  베이커리,카페
#
#                                                      cat2  review_num  \
# 115054  ['즉석우동\n6,000', '어묵우동\n7,000', '어묵 (1인분)\n6,00...        25.0
# 115055  ['즉석우동\n6,000', '어묵우동\n7,000', '어묵 (1인분)\n6,00...        25.0
# 115056  ['즉석우동\n6,000', '어묵우동\n7,000', '어묵 (1인분)\n6,00...        25.0
# 115057  ['즉석우동\n6,000', '어묵우동\n7,000', '어묵 (1인분)\n6,00...        25.0
# 115058  ['즉석우동\n6,000', '어묵우동\n7,000', '어묵 (1인분)\n6,00...        25.0
# ...                                                   ...         ...
# 130613  ['추천\n곰돌이도시락케이크\n21,000\n고정디자인 초코맛 당일예약가능(재고소진...         NaN
# 130614  ['추천\n곰돌이도시락케이크\n21,000\n고정디자인 초코맛 당일예약가능(재고소진...         NaN
# 130615  ['추천\n곰돌이도시락케이크\n21,000\n고정디자인 초코맛 당일예약가능(재고소진...         NaN
# 130616  ['추천\n곰돌이도시락케이크\n21,000\n고정디자인 초코맛 당일예약가능(재고소진...         NaN
# 130617  ['추천\n곰돌이도시락케이크\n21,000\n고정디자인 초코맛 당일예약가능(재고소진...         NaN
#
#         blog_review_num  score_min      likePoint likePointCnt  rate  \
# 115054              597        3.8  맛@가성비@친절@분위기@   16@11@6@1@   2.3
# 115055              597        3.8  맛@가성비@친절@분위기@   16@11@6@1@   1.7
# 115056              597        3.8  맛@가성비@친절@분위기@   16@11@6@1@   4.1
# 115057              597        3.8  맛@가성비@친절@분위기@   16@11@6@1@   4.3
# 115058              597        3.8  맛@가성비@친절@분위기@   16@11@6@1@   4.0
# ...                 ...        ...            ...          ...   ...
# 130613               18        4.8      맛@친절@분위기@       1@1@1@   5.0
# 130614               18        4.8      맛@친절@분위기@       1@1@1@   3.5
# 130615               18        4.8      맛@친절@분위기@       1@1@1@   4.9
# 130616               18        4.8      맛@친절@분위기@       1@1@1@   3.7
# 130617               18        4.8      맛@친절@분위기@       1@1@1@   5.0
#
#        reviewerCnt  reviewAt reviews_date         lon        lat  \
# 115054           3       1.0  2023.02.16.  126.911152  37.554239
# 115055           3       2.0  2023.02.11.  126.911152  37.554239
# 115056          15       4.0  2023.02.08.  126.911152  37.554239
# 115057         127       5.0  2023.02.04.  126.911152  37.554239
# 115058         117       4.0  2023.01.29.  126.911152  37.554239
# ...            ...       ...          ...         ...        ...
# 130613           2       5.0  2022.05.21.  126.908045  37.556836
# 130614         253       4.0  2022.04.24.  126.908045  37.556836
# 130615          35       5.0  2022.03.06.  126.908045  37.556836
# 130616          11       5.0  2022.02.08.  126.908045  37.556836
# 130617          10       5.0  2022.01.03.  126.908045  37.556836
#
#                                            url          open_time review  \
# 115054    https://place.map.kakao.com/15526158  월~토 11:00 ~ 22:00    NaN
# 115055    https://place.map.kakao.com/15526158  월~토 11:00 ~ 22:00    NaN
# 115056    https://place.map.kakao.com/15526158  월~토 11:00 ~ 22:00    NaN
# 115057    https://place.map.kakao.com/15526158  월~토 11:00 ~ 22:00    NaN
# 115058    https://place.map.kakao.com/15526158  월~토 11:00 ~ 22:00    NaN
# ...                                        ...                ...    ...
# 130613  https://place.map.kakao.com/1913867081   매일 11:00 ~ 20:00    NaN
# 130614  https://place.map.kakao.com/1913867081   매일 11:00 ~ 20:00    NaN
# 130615  https://place.map.kakao.com/1913867081   매일 11:00 ~ 20:00    NaN
# 130616  https://place.map.kakao.com/1913867081   매일 11:00 ~ 20:00    NaN
# 130617  https://place.map.kakao.com/1913867081   매일 11:00 ~ 20:00    NaN
#
#        reviewer_id
# 115054         NaN
# 115055         NaN
# 115056         NaN
# 115057         NaN
# 115058         NaN
# ...            ...
# 130613         NaN
# 130614         NaN
# 130615         NaN
# 130616         NaN
# 130617         NaN
#
# [15564 rows x 20 columns]

# %%
raw_set1 = set(raw1['region'].to_list())
raw_set2 = set(raw2['region'].to_list())
raw_set3 = set(raw3['region'].to_list())
raw_set3
# Out:
# {'가산디지털역',
#  '강남역',
#  '고려대역',
#  '공덕역',
#  '광명역',
#  '광안리',
#  '광흥창역',
#  '교대역',
#  '구산역',
#  '낙성대역',
#  '남부터미널역',
#  '녹사평역',
#  '당산역',
#  '대흥역',
#  '독바위역',
#  '돌곶이역',
#  '동묘앞역',
#  '디지털미디어시티역',
#  '마포구청역',
#  '망원',
#  '망원역',
#  '문래역',
#  '방배역',
#  '버티고개역',
#  '보문역',
#  '봉화산역',
#  '부산 수변공원',
#  '불광역',
#  '사당역',
#  '삼각지역',
#  '삼성',
#  '삼성역',
#  '삼성중앙역',
#  '상수역',
#  '상월곡역',
#  '새절역',
#  '서울대입구역',
#  '서초역',
#  '석계역',
#  '선릉역',
#  '선정릉역',
#  '속초',
#  '신당역',
#  '신도림역',
#  '신림역',
#  '신촌역',
#  '안암역',
#  '약수역',
#  '양재역',
#  '역삼역',
#  '역촌역',
#  '연신내역',
#  '영등포구청',
#  '오리역',
#  '월곡역',
#  '월드컵경기장역',
#  '응암역',
#  '이태원역',
#  '잠실나루역',
#  '잠실새내역',
#  '종합운동장역',
#  '증산역',
#  '창신역',
#  '청구역',
#  '태릉입구역',
#  '판교역',
#  '한강진역',
#  '합정',
#  '합정역',
#  '해운대',
#  '홍대입구역',
#  '화랑대역',
#  '효창공원앞역'}

# %%
list(raw_set1) + ['합정역']
# Out:
# ['합정', '삼성역', '역삼역', '홍대입구역', '합정역']

# %%
raw1
# Out:
#       region      name                              addresse     cat1  \
# 0        삼성역   팀호완 삼성점         서울 강남구 봉은사로86길 30 1층 (우)06165       중식
# 1         합정  어반플랜트 합정          서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 2         합정  어반플랜트 합정          서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 3         합정  어반플랜트 합정          서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 4         합정  어반플랜트 합정          서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# ...      ...       ...                                   ...      ...
# 39550    역삼역       카즈야           서울 강남구 테헤란로27길 8-4 (우)06141       한식
# 39551    역삼역       카즈야           서울 강남구 테헤란로27길 8-4 (우)06141       한식
# 39552    역삼역   호천당 역삼점  서울 강남구 테헤란로22길 15 A&C 빌딩 1층 (우)06236       한식
# 39553    역삼역   호천당 역삼점  서울 강남구 테헤란로22길 15 A&C 빌딩 1층 (우)06236       한식
# 39554    역삼역   호천당 역삼점  서울 강남구 테헤란로22길 15 A&C 빌딩 1층 (우)06236       한식
#
#                                                     cat2  review_num  \
# 0      샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 1      ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 2      ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 3      ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 4      ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# ...                                                  ...         ...
# 39550  ['생선가스\n8,000', '모듬까스\n11,000', '튀김우동\n8,000',...         1.0
# 39551  ['생선가스\n8,000', '모듬까스\n11,000', '튀김우동\n8,000',...         1.0
# 39552                                                 []         NaN
# 39553                                                 []         NaN
# 39554                                                 []         NaN
#
#        blog_review_num  score_min         likePoint   likePointCnt  rate  \
# 0                  824        3.5     맛@가성비@친절@분위기@       3@1@1@1@   3.8
# 1                  690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   3.8
# 2                  690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   4.2
# 3                  690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   3.6
# 4                  690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   4.4
# ...                ...        ...               ...            ...   ...
# 39550               12        4.4                맛@             1@   3.9
# 39551               12        4.4                맛@             1@   4.8
# 39552               35        4.5         맛@친절@분위기@         2@1@1@   3.9
# 39553               35        4.5         맛@친절@분위기@         2@1@1@   4.0
# 39554               35        4.5         맛@친절@분위기@         2@1@1@   4.4
#
#       reviewerCnt  reviewAt reviews_date            lon           lat  \
# 0             432       5.0  2022.09.02.  127.056865961  37.511448223
# 1              26       5.0  2023.02.01.           None          None
# 2              11       4.0  2023.02.01.           None          None
# 3             466       3.0  2023.01.19.           None          None
# 4             500       5.0  2023.01.10.           None          None
# ...           ...       ...          ...            ...           ...
# 39550          34       3.0  2023.02.13.           None          None
# 39551       1,072       5.0  2022.07.29.           None          None
# 39552          34       4.0  2023.02.13.           None          None
# 39553          21       4.0  2023.01.26.           None          None
# 39554         291       4.0  2023.01.12.           None          None
#
#                                                   review reviewer_id  \
# 0                                                    NaN         NaN
# 1                          친구랑 자주 가는 카페임. 커피가 부드러운편이라 좋음         횸횸횸
# 2                              겨울에 가니까 푸릇푸릇해서 기분이 절로 좋아짐          뽀앤
# 3                                                    NaN      cercle
# 4                                               어반도 좋아요.      Barcia
# ...                                                  ...         ...
# 39550  역삼역쪽에서 가까우면 가도 무난하지만선릉쪽으로 가까우면 와비사비가 돈까스는 더  나...          HT
# 39551                                                 ㅇㅇ      프로평가조류
# 39552  맛있지만 돈까스 양 자체는 아쉬움다른 돈까스 집에 비해 약간 더 기름짐점보, 슈퍼점...          HT
# 39553  라스트오더 20시 마감 20시30분정보 잘못됐어요가게는 밝고 깨끗하고 직원분 친절해...          죨디
# 39554  친절 맛 인테리어 활기찬 분위기 깔끔 1인석도있음 혼밥 치즈돈까스  점심식사  쟁반...          희망
#
#                                           url          open_time
# 0                                         NaN                NaN
# 1      https://place.map.kakao.com/1068887729                NaN
# 2      https://place.map.kakao.com/1068887729                NaN
# 3      https://place.map.kakao.com/1068887729                NaN
# 4      https://place.map.kakao.com/1068887729                NaN
# ...                                       ...                ...
# 39550    https://place.map.kakao.com/19789687   매일 11:30 ~ 23:00
# 39551    https://place.map.kakao.com/19789687   매일 11:30 ~ 23:00
# 39552   https://place.map.kakao.com/197866657  월~금 11:00 ~ 21:00
# 39553   https://place.map.kakao.com/197866657  월~금 11:00 ~ 21:00
# 39554   https://place.map.kakao.com/197866657  월~금 11:00 ~ 21:00
#
# [39555 rows x 20 columns]

# %%
raw_set2
# Out:
# {'가산디지털역',
#  '강남역',
#  '고려대역',
#  '공덕역',
#  '광명역',
#  '광안리',
#  '광흥창역',
#  '교대역',
#  '구산역',
#  '낙성대역',
#  '남부터미널역',
#  '녹사평역',
#  '당산역',
#  '대흥역',
#  '독바위역',
#  '돌곶이역',
#  '동묘앞역',
#  '디지털미디어시티역',
#  '마포구청역',
#  '망원',
#  '망원역',
#  '문래역',
#  '방배역',
#  '버티고개역',
#  '보문역',
#  '봉화산역',
#  '부산 수변공원',
#  '불광역',
#  '사당역',
#  '삼각지역',
#  '삼성',
#  '삼성역',
#  '삼성중앙역',
#  '상수역',
#  '상월곡역',
#  '새절역',
#  '서울대입구역',
#  '서초역',
#  '석계역',
#  '선릉역',
#  '선정릉역',
#  '속초',
#  '신당역',
#  '신도림역',
#  '신림역',
#  '신촌역',
#  '안암역',
#  '약수역',
#  '양재역',
#  '역삼역',
#  '역촌역',
#  '연신내역',
#  '영등포구청',
#  '오리역',
#  '월곡역',
#  '월드컵경기장역',
#  '응암역',
#  '이태원역',
#  '잠실나루역',
#  '잠실새내역',
#  '종합운동장역',
#  '증산역',
#  '창신역',
#  '청구역',
#  '태릉입구역',
#  '판교역',
#  '한강진역',
#  '합정',
#  '합정역',
#  '해운대',
#  '홍대입구역',
#  '화랑대역',
#  '효창공원앞역'}

# %%
raw_set1 - raw_set3
# Out:
# {'홍대입구역'}

# %%
hong_df = raw2[raw2['region'] == '홍대입구역']
hong_df = hong_df.drop_duplicates(subset=['review', 'reviewer_id', 'reviews_date', 'reviewAt'], keep='last')

# %%
all_df = pd.concat([raw1, gang_df, yang_df])

# %%
all_raw.drop_duplicates(subset=['review', 'reviewer_id', 'reviews_date', 'reviewAt'], keep='last')
# Out:
#        region        name                            addresse cat1  \
# 281        합정      스케줄 합정         서울 마포구 양화로6길 33 1층 (우)04044   양식
# 347        합정      스케줄 합정         서울 마포구 양화로6길 33 1층 (우)04044   양식
# 354        합정      스케줄 합정         서울 마포구 양화로6길 33 1층 (우)04044   양식
# 417        합정  오레노라멘 합정본점            서울 마포구 독막로6길 14 (우)04072   면류
# 693        합정  오레노라멘 합정본점            서울 마포구 독막로6길 14 (우)04072   면류
# ...       ...         ...                                 ...  ...
# 184525    양재역   강남역기와집양대창  서울 서초구 서초대로78길 52 1층 101호 (우)06626   육류
# 184526    양재역   강남역기와집양대창  서울 서초구 서초대로78길 52 1층 101호 (우)06626   육류
# 184527    양재역   강남역기와집양대창  서울 서초구 서초대로78길 52 1층 101호 (우)06626   육류
# 184528    양재역   강남역기와집양대창  서울 서초구 서초대로78길 52 1층 101호 (우)06626   육류
# 184529    양재역   강남역기와집양대창  서울 서초구 서초대로78길 52 1층 101호 (우)06626   육류
#
#                                                      cat2  review_num  \
# 281     ['추천\n스케줄김치볶음밥\n17,000', '차돌 대파 떡볶이\n26,000', ...         9.0
# 347     ['추천\n스케줄김치볶음밥\n17,000', '차돌 대파 떡볶이\n26,000', ...         9.0
# 354     ['추천\n스케줄김치볶음밥\n17,000', '차돌 대파 떡볶이\n26,000', ...         9.0
# 417     ['토리쇼유\n10,000', '시오라멘\n10,000', '카라빠이탄\n10,000']        48.0
# 693     ['토리쇼유\n10,000', '시오라멘\n10,000', '카라빠이탄\n10,000']        48.0
# ...                                                   ...         ...
# 184525  ['특양 (130g)\n19,000', '한우대창 (200g)\n17,000', '...         1.0
# 184526  ['특양 (130g)\n19,000', '한우대창 (200g)\n17,000', '...         1.0
# 184527  ['특양 (130g)\n19,000', '한우대창 (200g)\n17,000', '...         1.0
# 184528  ['특양 (130g)\n19,000', '한우대창 (200g)\n17,000', '...         1.0
# 184529  ['특양 (130g)\n19,000', '한우대창 (200g)\n17,000', '...         1.0
#
#         blog_review_num  score_min      likePoint  likePointCnt  rate  \
# 281                 885        3.8      분위기@맛@친절@        9@7@3@   3.8
# 347                 885        3.8      분위기@맛@친절@        9@7@3@   5.0
# 354                 885        3.8      분위기@맛@친절@        9@7@3@   3.5
# 417                 562        4.4  맛@친절@가성비@분위기@  49@27@25@14@   3.4
# 693                 562        4.4  맛@친절@가성비@분위기@  49@27@25@14@   4.7
# ...                 ...        ...            ...           ...   ...
# 184525              168        4.3             맛@            1@   4.1
# 184526              168        4.3             맛@            1@   4.8
# 184527              168        4.3             맛@            1@   4.3
# 184528              168        4.3             맛@            1@   4.3
# 184529              168        4.3             맛@            1@   5.0
#
#        reviewerCnt  reviewAt reviews_date   lon   lat  \
# 281            522       3.0  2022.09.02.  None  None
# 347              4       5.0  2022.02.16.  None  None
# 354            460       2.0  2021.12.07.  None  None
# 417             10       5.0  2022.10.16.  None  None
# 693             40       4.0  2020.11.03.  None  None
# ...            ...       ...          ...   ...   ...
# 184525          57       4.0  2020.03.29.  None  None
# 184526          18       5.0  2019.11.17.  None  None
# 184527          25       5.0  2019.09.06.  None  None
# 184528          18       3.0  2019.08.12.  None  None
# 184529           1       5.0  2019.06.16.  None  None
#
#                                                    review reviewer_id  \
# 281                                                   NaN         ㅋㅆㅇ
# 347                                              맛있어요!!!!         이지현
# 354                                                   NaN         123
# 417                                                   NaN           쿰
# 693                                                   NaN          KK
# ...                                                   ...         ...
# 184525                              맛있고 가격도 양대창집 치고 저렴한 편         이상민
# 184526  엄청 친절하시고 양 대창도 넘 맛있었어요ㅠㅠ스타일러에 옷 보관도 가능해서 넘 좋았어...         귀여미
# 184527  점심특선 7,500 원짜리가쇠고기전골에 강된장 비빔밥에 다채롭고 맛있는 반찬들~9천...        아자아자
# 184528  대창덮밥 기대하고 갔는데대창 양이 다른 집에 비해서 너무 적어요ㅠㅠ한우를 쓰신다고는...    소식하는 미식가
# 184529  시설도 너무좋고 너무친절하시고 고기 질도 너무좋고 양도많이주시고 너무좋아요 후식국수...          정윤
#
#                                            url          open_time
# 281     https://place.map.kakao.com/1068887729                NaN
# 347     https://place.map.kakao.com/1068887729                NaN
# 354     https://place.map.kakao.com/1068887729                NaN
# 417     https://place.map.kakao.com/1068887729                NaN
# 693     https://place.map.kakao.com/1068887729                NaN
# ...                                        ...                ...
# 184525  https://place.map.kakao.com/1727429798  월~금 11:30 ~ 22:30
# 184526  https://place.map.kakao.com/1727429798  월~금 11:30 ~ 22:30
# 184527  https://place.map.kakao.com/1727429798  월~금 11:30 ~ 22:30
# 184528  https://place.map.kakao.com/1727429798  월~금 11:30 ~ 22:30
# 184529  https://place.map.kakao.com/1727429798  월~금 11:30 ~ 22:30
#
# [58956 rows x 20 columns]

# %%
all_raw = pd.concat([raw1, raw2, raw3])

# %%
from collections import Counter
id_cnt = Counter(all_raw['reviewer_id'].to_list()).most_common()

# %%
tmp_df = all_raw.drop_duplicates(subset=['review', 'reviewer_id'], keep='last')

# %%
raw_all = all_raw.drop_duplicates(subset=['review', 'reviewer_id', 'reviews_date', 'reviewAt'], keep='last')

# %%
len(raw_all)
# Out:
# 52015

# %%
del raw_all['reviewer_id']
del raw_all['review']

# %%
all_df.to_csv('./result/matki_DB.csv', index=False, encoding='utf-8-sig')

# %%
all_df.to_csv('./result/matki_DB_raw.csv', index=False, encoding='utf-8-sig')

# %%
tmp = pd.read_csv('./result/matki_DB.csv')
# Out:
# /tmp/ipykernel_10017/1716225803.py:3: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmp = pd.read_csv('./result/matki_DB.csv')

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178544 entries, 0 to 178543
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   region           178544 non-null  object
#  1   name             178544 non-null  object
#  2   addresse         178544 non-null  object
#  3   cat1             178544 non-null  object
#  4   cat2             178392 non-null  object
#  5   review_num       169045 non-null  float64
#  6   blog_review_num  178544 non-null  int64
#  7   score_min        178544 non-null  float64
#  8   likePoint        168501 non-null  object
#  9   likePointCnt     168501 non-null  object
#  10  rate             178544 non-null  float64
#  11  reviewerCnt      178544 non-null  object
#  12  reviewAt         178544 non-null  float64
#  13  reviews_date     178544 non-null  object
#  14  lon              178544 non-null  float64
#  15  lat              178544 non-null  float64
#  16  url              99934 non-null   object
#  17  open_time        81654 non-null   object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 24.5+ MB

# %%
set(tmp['region'].to_list())
# Out:
# {'가산디지털역',
#  '강남역',
#  '고려대역',
#  '공덕역',
#  '광명역',
#  '광안리',
#  '광흥창역',
#  '교대역',
#  '구산역',
#  '낙성대역',
#  '남부터미널역',
#  '녹사평역',
#  '당산역',
#  '대흥역',
#  '독바위역',
#  '돌곶이역',
#  '동묘앞역',
#  '디지털미디어시티역',
#  '마포구청역',
#  '망원',
#  '망원역',
#  '문래역',
#  '방배역',
#  '버티고개역',
#  '보문역',
#  '봉화산역',
#  '부산 수변공원',
#  '불광역',
#  '사당역',
#  '삼각지역',
#  '삼성',
#  '삼성역',
#  '삼성중앙역',
#  '상수역',
#  '상월곡역',
#  '새절역',
#  '서울대입구역',
#  '서초역',
#  '석계역',
#  '선릉역',
#  '선정릉역',
#  '속초',
#  '신당역',
#  '신도림역',
#  '신림역',
#  '신촌역',
#  '안암역',
#  '약수역',
#  '양재역',
#  '역삼역',
#  '역촌역',
#  '연신내역',
#  '영등포구청',
#  '오리역',
#  '월곡역',
#  '월드컵경기장역',
#  '응암역',
#  '이태원역',
#  '잠실나루역',
#  '잠실새내역',
#  '종합운동장역',
#  '증산역',
#  '창신역',
#  '청구역',
#  '태릉입구역',
#  '판교역',
#  '한강진역',
#  '합정',
#  '합정역',
#  '해운대',
#  '홍대입구역',
#  '화랑대역',
#  '효창공원앞역'}

# %%
tmp_s = tmp[tmp['region']=='망원']
tmp_s.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 2
#       1 # tmp_s = tmp[tmp['region']=='망원']
# ----> 2 tmp_s.info()
#
# NameError: name 'tmp_s' is not defined

# %%
ad_df = pd.read_csv('./result/matki_DB.csv')
# Out:
# /tmp/ipykernel_6149/2484631542.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   ad_df = pd.read_csv('./result/matki_DB.csv')

# %%
ad_df.keys()
# Out:
# Index(['region', 'name', 'addresse', 'cat1', 'cat2', 'review_num',
#        'blog_review_num', 'score_min', 'likePoint', 'likePointCnt', 'rate',
#        'reviewerCnt', 'reviewAt', 'reviews_date', 'lon', 'lat', 'url',
#        'open_time'],
#       dtype='object')

# %%
ad_df.drop_duplicates(subset=['url'], keep='last')
# Out:
#        region         name                             addresse     cat1  \
# 78609    봉화산역       치킨과사람들  서울 중랑구 신내로 225 디아뜨갤러리 110호 (우)02024    패스트푸드
# 100423     합정         몰토베네           서울 마포구 성지3길 67 1층 (우)04072       양식
# 100712     합정   앤트러사이트 합정점             서울 마포구 토정로5길 10 (우)04073  베이커리,카페
# 101257     합정    빈브라더스 합정점             서울 마포구 토정로 35-1 (우)04083  베이커리,카페
# 103830     합정        시루케이크        서울 마포구 어울마당로1길 18 1층 (우)04073      떡카페
# ...       ...          ...                                  ...      ...
# 178472  홍대입구역          몽중식           서울 마포구 동교로 257 2층 (우)03983       중식
# 178474  홍대입구역  새마을식당 홍대서교점         서울 마포구 어울마당로 144 1층 (우)04053    새마을식당
# 178477  홍대입구역      경복궁 서교점             서울 마포구 월드컵북로 37 (우)04000       기타
# 178540  홍대입구역           뇽즈             서울 마포구 연희로 17-1 (우)03985       양식
# 178543  홍대입구역  비트포비아 홍대던전점        서울 마포구 독막로3길 30 지하2층 (우)04047     테마카페
#
#                                                      cat2  review_num  \
# 78609   ['핫베이크 치킨\n17,000\n튀기지 않아도 컽은 바삭바삭 속은 촉촉한 후라이드...         NaN
# 100423  ['마르게리따\n22,000', '살치살 스테이크 (250g)\n42,000', '...        12.0
# 100712  ['아메리카노(HOT)\n5,000', '카페라떼(HOT)\n5,500', '플랫화...        14.0
# 101257  ['핸드드립\n7,000', '원앤원\n6,000', '에스프레소\n6,000', ...        11.0
# 103830  ['아메리카노\n4,000', '카페라떼\n4,500', '플랫화이트\n4,500'...         6.0
# ...                                                   ...         ...
# 178472  ['[천장지구] 런치\n38,000\n총 6가지 메뉴로 진행됩니다.', '[천장지구...         4.0
# 178474  ['열탄불고기', '한돈생오겹살', '항정살', '차돌박이', '껍데기', '7분 ...         3.0
# 178477  ['숯불갈비살한정식\n29,000\n점심특선', '영양갈비찜한정식\n33,000\n...         1.0
# 178540  ['오므라이스\n8,000', '돈가스\n8,000', '토마토 치즈 돈가스\n10...         6.0
# 178543                                                 []         1.0
#
#         blog_review_num  score_min      likePoint likePointCnt  rate  \
# 78609                 2        5.0            NaN          NaN   3.0
# 100423              188        4.4  맛@분위기@친절@가성비@  16@16@13@2@   3.5
# 100712              242        3.5      분위기@맛@친절@       5@3@1@   4.0
# 101257              174        4.3  맛@친절@분위기@가성비@     5@3@3@1@   4.0
# 103830              145        4.5      맛@친절@분위기@       3@2@2@   3.8
# ...                 ...        ...            ...          ...   ...
# 178472              273        4.2  맛@친절@분위기@가성비@     8@7@7@6@   4.2
# 178474               36        2.0            NaN          NaN   2.1
# 178477               32        1.9          맛@주차@         1@1@   5.0
# 178540               93        4.0  맛@가성비@친절@분위기@     4@2@1@1@   2.8
# 178543              149        4.1           분위기@           1@   4.5
#
#        reviewerCnt  reviewAt reviews_date         lon        lat  \
# 78609            2       5.0  2020.08.21.  127.091213  37.617065
# 100423         198       5.0  2018.12.19.  126.916671  37.546256
# 100712       1,028       5.0  2016.03.09.  126.918277  37.545819
# 101257       1,028       4.0  2016.03.09.  126.914981  37.545723
# 103830           9       5.0  2018.08.23.  126.918270  37.546785
# ...            ...       ...          ...         ...        ...
# 178472         530       4.0  2023.01.20.  126.924655  37.562834
# 178474          14       1.0  2022.09.08.  126.925834  37.556198
# 178477           2       5.0  2022.11.06.  126.918158  37.557628
# 178540          40       4.0  2018.10.17.  126.926410  37.560468
# 178543           8       5.0  2022.05.31.  126.917355  37.549572
#
#                                            url                      open_time
# 78609                                      NaN                            NaN
# 100423   https://place.map.kakao.com/926080103                        제공하지 않음
# 100712    https://place.map.kakao.com/12518512               매일 09:00 ~ 22:00
# 101257    https://place.map.kakao.com/24855092               매일 11:00 ~ 21:00
# 103830   https://place.map.kakao.com/436951953              월~토 11:00 ~ 21:00
# ...                                        ...                            ...
# 178472  https://place.map.kakao.com/1748774897               매일 12:00 ~ 21:30
# 178474    https://place.map.kakao.com/11825088               매일 00:00 ~ 24:00
# 178477     https://place.map.kakao.com/8332117               매일 11:30 ~ 22:00
# 178540   https://place.map.kakao.com/644888486  매일 11:30 ~ 22:00 (재료소진시 조기마감)
# 178543  https://place.map.kakao.com/1246652450               매일 12:00 ~ 24:00
#
# [2422 rows x 18 columns]

# %%
ad_df
# Out:
#        region         name                       addresse  cat1  \
# 0         삼성역      팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165    중식
# 1         삼성역      팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165    중식
# 2         삼성역      팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165    중식
# 3         삼성역      팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165    중식
# 4         삼성역      팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165    중식
# ...       ...          ...                            ...   ...
# 178539  홍대입구역           뇽즈       서울 마포구 연희로 17-1 (우)03985    양식
# 178540  홍대입구역           뇽즈       서울 마포구 연희로 17-1 (우)03985    양식
# 178541  홍대입구역  비트포비아 홍대던전점  서울 마포구 독막로3길 30 지하2층 (우)04047  테마카페
# 178542  홍대입구역  비트포비아 홍대던전점  서울 마포구 독막로3길 30 지하2층 (우)04047  테마카페
# 178543  홍대입구역  비트포비아 홍대던전점  서울 마포구 독막로3길 30 지하2층 (우)04047  테마카페
#
#                                                      cat2  review_num  \
# 0       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 1       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 2       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 3       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 4       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# ...                                                   ...         ...
# 178539  ['오므라이스\n8,000', '돈가스\n8,000', '토마토 치즈 돈가스\n10...         6.0
# 178540  ['오므라이스\n8,000', '돈가스\n8,000', '토마토 치즈 돈가스\n10...         6.0
# 178541                                                 []         1.0
# 178542                                                 []         1.0
# 178543                                                 []         1.0
#
#         blog_review_num  score_min      likePoint likePointCnt  rate  \
# 0                   824        3.5  맛@가성비@친절@분위기@     3@1@1@1@   3.8
# 1                   824        3.5  맛@가성비@친절@분위기@     3@1@1@1@   3.3
# 2                   824        3.5  맛@가성비@친절@분위기@     3@1@1@1@   3.4
# 3                   824        3.5  맛@가성비@친절@분위기@     3@1@1@1@   2.6
# 4                   824        3.5  맛@가성비@친절@분위기@     3@1@1@1@   3.5
# ...                 ...        ...            ...          ...   ...
# 178539               93        4.0  맛@가성비@친절@분위기@     4@2@1@1@   4.6
# 178540               93        4.0  맛@가성비@친절@분위기@     4@2@1@1@   2.8
# 178541              149        4.1           분위기@           1@   4.5
# 178542              149        4.1           분위기@           1@   4.4
# 178543              149        4.1           분위기@           1@   4.5
#
#        reviewerCnt  reviewAt reviews_date         lon        lat  \
# 0              432       5.0  2022.09.02.  127.056866  37.511448
# 1               66       4.0  2022.09.01.  127.056866  37.511448
# 2               35       5.0  2022.08.18.  127.056866  37.511448
# 3               73       4.0  2022.08.10.  127.056866  37.511448
# 4               84       4.0  2022.06.29.  127.056866  37.511448
# ...            ...       ...          ...         ...        ...
# 178539          93       5.0  2019.05.18.  126.926410  37.560468
# 178540          40       4.0  2018.10.17.  126.926410  37.560468
# 178541          67       5.0  2023.02.09.  126.917355  37.549572
# 178542          13       2.0  2022.07.12.  126.917355  37.549572
# 178543           8       5.0  2022.05.31.  126.917355  37.549572
#
#                                            url                      open_time
# 0                                          NaN                            NaN
# 1                                          NaN                            NaN
# 2                                          NaN                            NaN
# 3                                          NaN                            NaN
# 4                                          NaN                            NaN
# ...                                        ...                            ...
# 178539   https://place.map.kakao.com/644888486  매일 11:30 ~ 22:00 (재료소진시 조기마감)
# 178540   https://place.map.kakao.com/644888486  매일 11:30 ~ 22:00 (재료소진시 조기마감)
# 178541  https://place.map.kakao.com/1246652450               매일 12:00 ~ 24:00
# 178542  https://place.map.kakao.com/1246652450               매일 12:00 ~ 24:00
# 178543  https://place.map.kakao.com/1246652450               매일 12:00 ~ 24:00
#
# [178544 rows x 18 columns]

# %%
ad_df.keys()
# Out:
# Index(['region', 'name', 'addresse', 'cat1', 'cat2', 'review_num',
#        'blog_review_num', 'score_min', 'likePoint', 'likePointCnt', 'rate',
#        'reviewerCnt', 'reviewAt', 'reviews_date', 'lon', 'lat', 'url',
#        'open_time'],
#       dtype='object')

# %%
ad_df.iloc[:,[2,14,15]]
# Out:
#                              addresse         lon        lat
# 0       서울 강남구 봉은사로86길 30 1층 (우)06165  127.056866  37.511448
# 1       서울 강남구 봉은사로86길 30 1층 (우)06165  127.056866  37.511448
# 2       서울 강남구 봉은사로86길 30 1층 (우)06165  127.056866  37.511448
# 3       서울 강남구 봉은사로86길 30 1층 (우)06165  127.056866  37.511448
# 4       서울 강남구 봉은사로86길 30 1층 (우)06165  127.056866  37.511448
# ...                               ...         ...        ...
# 195053      서울 서대문구 연세로7길 22 (우)03788  126.935556  37.557772
# 195054      서울 서대문구 연세로7길 22 (우)03788  126.935556  37.557772
# 195055      서울 서대문구 연세로7길 22 (우)03788  126.935556  37.557772
# 195056      서울 서대문구 연세로7길 22 (우)03788  126.935556  37.557772
# 195057      서울 서대문구 연세로7길 22 (우)03788  126.935556  37.557772
#
# [195058 rows x 3 columns]

# %%
result_dict = ad_df.set_index('addresse')[['lon', 'lat']].apply(tuple, axis=1).to_dict()

# %%
import numpy as np
def samedict(address):
    if type(address) != np.nan:
        try:
            if result_dict[address]:
                return result_dict[address][0],result_dict[address][1]
            else:
                return 'None', 'None'
        except:
            pass

all_df['lon'], all_df['lat'] = zip(*all_df['addresse'].apply(samedict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [74], line 12
#       9         except:
#      10             pass
# ---> 12 all_df['lon'], all_df['lat'] = zip(*all_df['addresse'].apply(samedict))
#
# TypeError: 'NoneType' object is not iterable

# %%
all_df

# %%
# 'address'를 기준으로 데이터프레임 합치기
merged_df = pd.merge(ad_df[['addresse', 'lon', 'lat']], all_df[['addresse', 'lon', 'lat']], on='addresse', suffixes=('_1', '_2'))

# 'lon'과 'lat' 열이 모두 NaN이 아닌 경우에 값을 덮어씌우기
merged_df.loc[merged_df['lon_1'].notnull() & merged_df['lon_2'].notnull(), ['lon_1', 'lat_1']] = merged_df.loc[merged_df['lon_1'].notnull() & merged_df['lon_2'].notnull(), ['lon_2', 'lat_2']]

# 결과 출력
print(merged_df[['addresse', 'lon_1', 'lat_1']])
# Out:
#                                  addresse  lon_1  lat_1
# 0           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN
# 1           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN
# 2           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN
# 3           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN
# 4           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN
# ...                                   ...    ...    ...
# 29267057  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN
# 29267058  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN
# 29267059  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN
# 29267060  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN
# 29267061  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN
#
# [29267062 rows x 3 columns]

# %%
merged_df
# Out:
#                                  addresse  lon_1  lat_1          lon_2  \
# 0           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN  127.056865961
# 1           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN  127.056865961
# 2           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN  127.056865961
# 3           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN  127.056865961
# 4           서울 강남구 봉은사로86길 30 1층 (우)06165    NaN    NaN  127.056865961
# ...                                   ...    ...    ...            ...
# 29267057  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN           None
# 29267058  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN           None
# 29267059  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN           None
# 29267060  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN           None
# 29267061  서울 마포구 와우산로29길 4-40 1층 (우)04052    NaN    NaN           None
#
#                  lat_2
# 0         37.511448223
# 1         37.511448223
# 2         37.511448223
# 3         37.511448223
# 4         37.511448223
# ...                ...
# 29267057          None
# 29267058          None
# 29267059          None
# 29267060          None
# 29267061          None
#
# [29267062 rows x 5 columns]

# %%
pd.concat([all_df,ad_df])
# Out:
#        region      name                       addresse     cat1  \
# 0         삼성역   팀호완 삼성점  서울 강남구 봉은사로86길 30 1층 (우)06165       중식
# 1          합정  어반플랜트 합정   서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 2          합정  어반플랜트 합정   서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 3          합정  어반플랜트 합정   서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# 4          합정  어반플랜트 합정   서울 마포구 독막로4길 3 1~3층 (우)04072  베이커리,카페
# ...       ...       ...                            ...      ...
# 195053   광흥창역     술익는마을      서울 서대문구 연세로7길 22 (우)03788       술집
# 195054   광흥창역     술익는마을      서울 서대문구 연세로7길 22 (우)03788       술집
# 195055   광흥창역     술익는마을      서울 서대문구 연세로7길 22 (우)03788       술집
# 195056   광흥창역     술익는마을      서울 서대문구 연세로7길 22 (우)03788       술집
# 195057   광흥창역     술익는마을      서울 서대문구 연세로7길 22 (우)03788       술집
#
#                                                      cat2  review_num  \
# 0       샤오마이 3pcs ->가격:6500 차슈 라이스 롤 3pcs ->가격:8000 사천...        17.0
# 1       ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 2       ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 3       ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# 4       ['Special Caprese\n15,800\n신선한 토마토와 생모짜렐라치즈가 들...        27.0
# ...                                                   ...         ...
# 195053  ['광어 사시미 (소)\n17,000', '연어 사시미\n23,000', '해물파전...         2.0
# 195054  ['광어 사시미 (소)\n17,000', '연어 사시미\n23,000', '해물파전...         2.0
# 195055  ['광어 사시미 (소)\n17,000', '연어 사시미\n23,000', '해물파전...         2.0
# 195056  ['광어 사시미 (소)\n17,000', '연어 사시미\n23,000', '해물파전...         2.0
# 195057  ['광어 사시미 (소)\n17,000', '연어 사시미\n23,000', '해물파전...         2.0
#
#         blog_review_num  score_min         likePoint   likePointCnt  rate  \
# 0                   824        3.5     맛@가성비@친절@분위기@       3@1@1@1@   3.8
# 1                   690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   3.8
# 2                   690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   4.2
# 3                   690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   3.6
# 4                   690        4.2  분위기@맛@친절@가성비@주차@  22@14@13@5@2@   4.4
# ...                 ...        ...               ...            ...   ...
# 195053               29        3.4         맛@친절@분위기@         3@1@1@   3.6
# 195054               29        3.4         맛@친절@분위기@         3@1@1@   3.6
# 195055               29        3.4         맛@친절@분위기@         3@1@1@   4.2
# 195056               29        3.4         맛@친절@분위기@         3@1@1@   4.0
# 195057               29        3.4         맛@친절@분위기@         3@1@1@   1.7
#
#        reviewerCnt  reviewAt reviews_date            lon           lat  \
# 0              432       5.0  2022.09.02.  127.056865961  37.511448223
# 1               26       5.0  2023.02.01.           None          None
# 2               11       4.0  2023.02.01.           None          None
# 3              466       3.0  2023.01.19.           None          None
# 4              500       5.0  2023.01.10.           None          None
# ...            ...       ...          ...            ...           ...
# 195053       1,245       1.0  2019.10.15.     126.935556     37.557772
# 195054          24       1.0  2019.01.09.     126.935556     37.557772
# 195055           9       1.0  2018.11.27.     126.935556     37.557772
# 195056          74       4.0  2018.11.17.     126.935556     37.557772
# 195057          27       1.0  2018.08.07.     126.935556     37.557772
#
#                                review reviewer_id  \
# 0                                 NaN         NaN
# 1       친구랑 자주 가는 카페임. 커피가 부드러운편이라 좋음         횸횸횸
# 2           겨울에 가니까 푸릇푸릇해서 기분이 절로 좋아짐          뽀앤
# 3                                 NaN      cercle
# 4                            어반도 좋아요.      Barcia
# ...                               ...         ...
# 195053                            NaN         NaN
# 195054                            NaN         NaN
# 195055                            NaN         NaN
# 195056                            NaN         NaN
# 195057                            NaN         NaN
#
#                                            url open_time
# 0                                          NaN       NaN
# 1       https://place.map.kakao.com/1068887729       NaN
# 2       https://place.map.kakao.com/1068887729       NaN
# 3       https://place.map.kakao.com/1068887729       NaN
# 4       https://place.map.kakao.com/1068887729       NaN
# ...                                        ...       ...
# 195053     https://place.map.kakao.com/9851414   제공하지 않음
# 195054     https://place.map.kakao.com/9851414   제공하지 않음
# 195055     https://place.map.kakao.com/9851414   제공하지 않음
# 195056     https://place.map.kakao.com/9851414   제공하지 않음
# 195057     https://place.map.kakao.com/9851414   제공하지 않음
#
# [252949 rows x 20 columns]

# %% [markdown]
# # 크롤러 수정

# %%
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    moreviews = soup.find_all(name="a", attrs={"class": "moreview"})

# %%
moreviews[0]["href"]
# Out:
# 'https://place.map.kakao.com/677576945'

# %%
import os
import re
from time import sleep
import requests
from geopy.geocoders import Nominatim

import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import (
    ElementNotInteractableException,
    NoSuchElementException,
    StaleElementReferenceException,
)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

from tqdm import tqdm
tqdm.pandas()
##############################################################  ############
##################### variable related geo ##########################
##########################################################################
def get_coordinates(address):
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None, None



def geocode(address, address_type="road"):
    address = " ".join(address.split(' ')[:4])
    apiurl = "http://api.vworld.kr/req/address?"
    params = {
        "service": "address",
        "request": "getcoord",
        "crs": "epsg:4326",
        "address": address,
        "format": "json",
        "type": address_type,
        "key": geocodeKey,#st.secrets["geocodeKey"],
    }
    
    try:
        response = requests.get(apiurl, params=params)

        json_data = response.json()

        if json_data["response"]["status"] == "OK":
            x = json_data["response"]["result"]["point"]["x"]
            y = json_data["response"]["result"]["point"]["y"]
            return (x, y)
        else:
            params['type'] = 'parcel'
            response = requests.get(apiurl, params=params)

            json_data = response.json()
            x = json_data["response"]["result"]["point"]["x"]
            y = json_data["response"]["result"]["point"]["y"]

            return (x, y)

    except Exception as e:
        location = geolocator.geocode(address)
        print(location)
        if location:
            return (location.latitude, location.longitude)
        else:
            print('주소가 없네요.', address)
            return ("None", "None")

##############################################################  ############
##################### variable related selenium ##########################
##########################################################################
options = webdriver.ChromeOptions()
options.add_argument("lang=ko_KR")
# options.add_argument("headless")
options.add_argument("window-size=1920x1080")
options.add_argument("disable-gpu")

# chromedriver_path = "/home/elinha/Testproject/mediapipe/chromedriver"
# 크롬 드라이버를 사용합니다 (맥은 첫 줄, 윈도우는 두번째 줄 실행)
driver = webdriver.Chrome(executable_path=ChromeDriverManager().install(), options=options)
geolocator = Nominatim(user_agent="geoapiExercises")
# matki_all = pd.read_csv("./matki_DB_raw.csv")


source_url = "https://map.kakao.com/"
# , "망원", "삼성", "삼성중앙", "선정릉", "신논현", "광흥창", "신촌", "양재", "역삼", "종로3가", "을지로3가", "영등포구청", "문래", "당산"
region = "마포구청"+"역"
# 합정, 망원, 삼성, 삼성중앙, 선정릉, 신논현, 당산, 홍대입구, 역삼역, 광흥창, 신촌
print(f'{region}을 시작합니다.')
# 크롬 드라이버를 사용합니다 (맥은 첫 줄, 윈도우는 두번째 줄 실행)


# 카카오 지도에 접속합니다
driver.get(source_url)
# 검색창에 검색어를 입력합니다
searchbox = driver.find_element(By.XPATH, "//input[@id='search.keyword.query']")
searchbox.send_keys("{0} 맛집".format(region))

# 검색버튼을 눌러서 결과를 가져옵니다
searchbutton = driver.find_element(By.XPATH, "//button[@id='search.keyword.submit']")
driver.execute_script("arguments[0].click();", searchbutton)

# 검색 결과를 가져올 시간을 기다립니다
sleep(2)

# 검색 결과의 페이지 소스를 가져옵니다
html = driver.page_source


driver.find_element(By.XPATH, "/html/body/div[10]/div/div/div/span").click()
sleep(2)
# 더보기 클릭
driver.find_element(By.XPATH, "//*[@id='info.search.place.more']").click()
sleep(2)
# 1~ 5페이지 링크 얻기
page_urls = []
cnt = 0

while driver.find_element(By.XPATH, '//a[@id="info.search.page.no5"]').is_displayed():
    for i in range(1, 6):
        page = driver.find_element(By.ID, "info.search.page.no" + str(i))
        page.click()
        sleep(2)

        urls = driver.find_elements(By.LINK_TEXT, "상세보기")
        page_urls.extend([urls[j].get_attribute("href") for j in range(len(urls))])
        print(driver.current_url)
    if (not bool(10 % 5)) & (
        not bool(driver.find_elements(By.XPATH, '//button[@class="next disabled"]'))
    ):
        driver.find_elements(By.XPATH, '//button[@id="info.search.page.next"]')[
            0
        ].click()
# Out:
# <ipython-input-55-fc2a8f91b541>:87: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=ChromeDriverManager().install(), options=options)
# 마포구청역을 시작합니다.

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
moreviews = soup.find_all(name="a", attrs={"class": "moreview"})

# %%
https://developers.kakao.com/docs/latest/ko/local/dev-guide#search-by-keyword-sample

# %%
import requests
from bs4 import BeautifulSoup

region = ""
all_df = pd.DataFrame()
url = "https://dapi.kakao.com/v2/local/search/keyword.json"
REST_API_KEY = "56f2996078b111211db16eba25db2d59"
headers = {"Authorization": f"KakaoAK {REST_API_KEY}"}
params = {
    "radius" : "20000",
    "category_group_code" : "FD6",
    "query": f"{region} 맛집"
}

for i in range(1,46):
    params['page'] = str(i)
    response = requests.get(url, headers=headers, params=params)
    tmp_json = response.json()['documents']
    df = pd.DataFrame(tmp_json)
    all_df = pd.concat([all_df, df])

# %%
all_df = all_df.rename(columns={
    'x': 'diner_lat',
    'y' : 'diner_lon',
    'road_address_name': 'diner_address',
    'place_name' : 'diner_name',
    'category_name' : 'diner_category',
    'phone' : 'diner_phone',
    'id' : 'diner_id'
    })

# %%
all_df = all_df.rename(columns={
    'road_address_name': 'diner_address',
    'place_name' : 'diner_name',
    'category_name' : 'diner_category',
    'phone' : 'diner_phone',
    'id' : 'diner_id'
    })

# %%
all_df
# Out:
#           address_name category_group_code category_group_name  \
# 0    서울 강남구 대치동 996-16                 FD6                 음식점
# 1     서울 강남구 대치동 956-6                 FD6                 음식점
# 2     서울 강남구 대치동 996-1                 FD6                 음식점
# 3    서울 강남구 대치동 942-10                 FD6                 음식점
# 4       서울 강남구 대치동 999                 FD6                 음식점
# ..                 ...                 ...                 ...
# 10  서울 서초구 서초동 1363-25                 FD6                 음식점
# 11   서울 강남구 도곡동 959-15                 FD6                 음식점
# 12   서울 서초구 양재동 11-149                 FD6                 음식점
# 13   서울 강남구 도곡동 954-10                 FD6                 음식점
# 14     서울 서초구 양재동 11-7                 FD6                 음식점
#
#               category_name distance          id           phone  \
# 0            음식점 > 한식 > 해장국             27531028     02-558-7905
# 1                  음식점 > 일식           1337569618     02-544-8422
# 2            음식점 > 양식 > 햄버거            586363951     02-566-6244
# 3          음식점 > 뷔페 > 해산물뷔페              7891904    02-3288-8080
# 4         음식점 > 일식 > 돈까스,우동             10042991  0507-1489-9805
# ..                      ...      ...         ...             ...
# 10                 음식점 > 한식             26890199     02-582-5044
# 11                 음식점 > 분식             16060644     02-571-7500
# 12  음식점 > 양식 > 이탈리안 > 라그릴리아             18373278     02-553-9192
# 13       음식점 > 간식 > 제과,베이커리            313181622   010-8655-2396
# 14    음식점 > 한식 > 육류,고기 > 갈비              8129543     02-571-3690
#
#       place_name                              place_url     road_address_name  \
# 0           중앙해장    http://place.map.kakao.com/27531028     서울 강남구 영동대로86길 17
# 1         부타이 1막  http://place.map.kakao.com/1337569618     서울 강남구 테헤란로88길 22
# 2   크라이치즈버거 삼성역점   http://place.map.kakao.com/586363951       서울 강남구 테헤란로 620
# 3    보노보노플러스 삼성점     http://place.map.kakao.com/7891904       서울 강남구 테헤란로 508
# 4     후레쉬빌 삼성역본점    http://place.map.kakao.com/10042991    서울 강남구 테헤란로108길 19
# ..           ...                                    ...                   ...
# 10     순남시래기 양재점    http://place.map.kakao.com/26890199  서울 서초구 강남대로39길 15-10
# 11  그린네은쟁반 양재역본점    http://place.map.kakao.com/16060644   서울 강남구 남부순환로359길 16
# 12     라그릴리아 양재점    http://place.map.kakao.com/18373278     서울 서초구 남부순환로 2620
# 13        호두까끼형제   http://place.map.kakao.com/313181622   서울 강남구 남부순환로351길 10
# 14     갈비세상 양재본점     http://place.map.kakao.com/8129543   서울 서초구 남부순환로350길 17
#
#              diner_lat           diner_lon
# 0     127.065472540919     37.508273597184
# 1   127.06004648139945  37.506171732639025
# 2   127.06553778419345  37.509160149568245
# 3    127.0580429637442  37.506940390349726
# 4     127.066264232804    37.5082479275874
# ..                 ...                 ...
# 10    127.031957594046    37.4857874836153
# 11    127.036602541856     37.486005981919
# 12    127.037293808058    37.4845713604873
# 13  127.03473440992505   37.48548756514254
# 14  127.03587342774496   37.48401317503263
#
# [1350 rows x 12 columns]

# %%
'category_name'

# %%
tmp_json[0]
# Out:
# {'address_name': '서울 영등포구 문래동2가 42-2',
#  'category_group_code': 'FD6',
#  'category_group_name': '음식점',
#  'category_name': '음식점 > 한식 > 육류,고기 > 오리',
#  'distance': '',
#  'id': '218867054',
#  'phone': '02-2676-1387',
#  'place_name': '골목오리집',
#  'place_url': 'http://place.map.kakao.com/218867054',
#  'road_address_name': '서울 영등포구 도림로139가길 11',
#  'x': '126.89312256591685',
#  'y': '37.513375510146645'}

# %%
tmp_json
# Out:
# [{'address_name': '서울 영등포구 문래동2가 48-6',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기 > 족발,보쌈',
#   'distance': '',
#   'id': '1210497999',
#   'phone': '02-6104-6453',
#   'place_name': '그믐족발 본점',
#   'place_url': 'http://place.map.kakao.com/1210497999',
#   'road_address_name': '서울 영등포구 경인로79길 21',
#   'x': '126.89306580543459',
#   'y': '37.5135196193597'},
#  {'address_name': '서울 영등포구 문래동2가 42-19',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 간식 > 제과,베이커리',
#   'distance': '',
#   'id': '1456174621',
#   'phone': '070-8805-0815',
#   'place_name': '러스트베이커리',
#   'place_url': 'http://place.map.kakao.com/1456174621',
#   'road_address_name': '서울 영등포구 경인로79길 15',
#   'x': '126.89371100418617',
#   'y': '37.513186830345816'},
#  {'address_name': '서울 영등포구 영등포동3가 7-32',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 냉면',
#   'distance': '',
#   'id': '10643743',
#   'phone': '02-2678-2722',
#   'place_name': '함흥냉면',
#   'place_url': 'http://place.map.kakao.com/10643743',
#   'road_address_name': '서울 영등포구 영등포로42길 6',
#   'x': '126.906790582264',
#   'y': '37.5189660993437'},
#  {'address_name': '서울 영등포구 여의도동 35-5',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 일식 > 초밥,롤',
#   'distance': '',
#   'id': '1247032398',
#   'phone': '',
#   'place_name': '아루히',
#   'place_url': 'http://place.map.kakao.com/1247032398',
#   'road_address_name': '서울 영등포구 여의나루로 42',
#   'x': '126.924972958655',
#   'y': '37.5214694204797'},
#  {'address_name': '서울 영등포구 여의도동 14-15',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 일식 > 초밥,롤',
#   'distance': '',
#   'id': '26602766',
#   'phone': '02-761-6200',
#   'place_name': '동해도 본점',
#   'place_url': 'http://place.map.kakao.com/26602766',
#   'road_address_name': '서울 영등포구 은행로 25',
#   'x': '126.921386202934',
#   'y': '37.5286895201804'},
#  {'address_name': '서울 영등포구 여의도동 44-3',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기',
#   'distance': '',
#   'id': '12643139',
#   'phone': '02-783-8800',
#   'place_name': '흑돈가 여의도직영점',
#   'place_url': 'http://place.map.kakao.com/12643139',
#   'road_address_name': '서울 영등포구 여의대방로69길 23',
#   'x': '126.93014883876948',
#   'y': '37.520880636180465'},
#  {'address_name': '서울 영등포구 신길동 258-10',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 설렁탕',
#   'distance': '',
#   'id': '2030217673',
#   'phone': '02-832-6687',
#   'place_name': '대한옥 2호점',
#   'place_url': 'http://place.map.kakao.com/2030217673',
#   'road_address_name': '서울 영등포구 가마산로69가길 7',
#   'x': '126.908946023078',
#   'y': '37.5064185985168'},
#  {'address_name': '서울 영등포구 문래동4가 9-2',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 육류,고기 > 닭요리',
#   'distance': '',
#   'id': '11279164',
#   'phone': '02-2677-7373',
#   'place_name': '능이버섯백숙',
#   'place_url': 'http://place.map.kakao.com/11279164',
#   'road_address_name': '서울 영등포구 선유로 32',
#   'x': '126.888871445967',
#   'y': '37.5167341317029'},
#  {'address_name': '서울 영등포구 여의도동 60',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 뷔페',
#   'distance': '',
#   'id': '7967166',
#   'phone': '02-789-5731',
#   'place_name': '63뷔페 파빌리온',
#   'place_url': 'http://place.map.kakao.com/7967166',
#   'road_address_name': '서울 영등포구 63로 50',
#   'x': '126.9401710888746',
#   'y': '37.51981484576526'},
#  {'address_name': '서울 영등포구 여의도동 15-24',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 곰탕',
#   'distance': '',
#   'id': '22211975',
#   'phone': '02-785-9292',
#   'place_name': '하동관 국회의사당역직영점',
#   'place_url': 'http://place.map.kakao.com/22211975',
#   'road_address_name': '서울 영등포구 은행로 3',
#   'x': '126.91962145659404',
#   'y': '37.5275170302225'},
#  {'address_name': '서울 영등포구 영등포동3가 15-1',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 해물,생선',
#   'distance': '',
#   'id': '12354234',
#   'phone': '02-2678-8482',
#   'place_name': '여로집 본관',
#   'place_url': 'http://place.map.kakao.com/12354234',
#   'road_address_name': '서울 영등포구 영중로10길 26',
#   'x': '126.908180003634',
#   'y': '37.5186968867654'},
#  {'address_name': '서울 영등포구 문래동3가 77-8',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 간식 > 제과,베이커리',
#   'distance': '',
#   'id': '15825589',
#   'phone': '0507-1371-9010',
#   'place_name': '쉐프조',
#   'place_url': 'http://place.map.kakao.com/15825589',
#   'road_address_name': '서울 영등포구 문래로 98',
#   'x': '126.89278049720974',
#   'y': '37.51924343410847'},
#  {'address_name': '서울 영등포구 문래동4가 6-5',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 한식 > 순대',
#   'distance': '',
#   'id': '24040605',
#   'phone': '02-2677-4183',
#   'place_name': '오복순대국',
#   'place_url': 'http://place.map.kakao.com/24040605',
#   'road_address_name': '서울 영등포구 도림로 465',
#   'x': '126.89156501552227',
#   'y': '37.51574102668877'},
#  {'address_name': '서울 영등포구 여의도동 24-1',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 양식 > 햄버거',
#   'distance': '',
#   'id': '1165592124',
#   'phone': '02-784-6643',
#   'place_name': '바스버거 여의도점',
#   'place_url': 'http://place.map.kakao.com/1165592124',
#   'road_address_name': '서울 영등포구 국제금융로 20',
#   'x': '126.92729317451683',
#   'y': '37.52488026462298'},
#  {'address_name': '서울 영등포구 영등포동4가 148-1',
#   'category_group_code': 'FD6',
#   'category_group_name': '음식점',
#   'category_name': '음식점 > 일식 > 초밥,롤',
#   'distance': '',
#   'id': '115297933',
#   'phone': '02-2677-5460',
#   'place_name': '스시나베',
#   'place_url': 'http://place.map.kakao.com/115297933',
#   'road_address_name': '서울 영등포구 영등포로 190-1',
#   'x': '126.902563005268',
#   'y': '37.5201051589945'}]

# %%
len(tmp_json)
# Out:
# 15

# %%
response.json()['meta']
# Out:
# {'is_end': True,
#  'pageable_count': 45,
#  'same_name': {'keyword': '맛집', 'region': [], 'selected_region': '서울 영등포구'},
#  'total_count': 49016}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 moreviews = response.find_all(name="a", attrs={"class": "moreview"})
#
# AttributeError: 'Response' object has no attribute 'find_all'

# %%
# columns = [
#     "region",
#     "name",
#     "addresse",
#     "cat1",
#     "cat2",
#     "review_num",
#     "blog_review_num",
#     "open_time",
#     "score_min",
#     "likePoint",
#     "likePointCnt",
#     "rate",
#     "reviewerCnt",
#     "reviewAt",
#     "review",
#     "reviews_date",
#     "reviewer_id"
# ]

columns = ['diner_name',           # 가게이름
        'diner_address',        # 가게 주소 
        'diner_category',       # 가게 카테고리
        'diner_menu',           # 가게 메뉴
        'diner_review_cnt',     # 가게의 평점 개수 
        'diner_review_avg',     # 가게의 평점 평균    
        'review_tags',          # 리뷰 태그 
        'reviewer_avg',         # 리뷰어의 평균
        'reviewer_review_cnt',  # 리뷰어의 리뷰 개수
        'reviewer_review',      # 리뷰어가 남긴 평점
        'review_date',          # 리뷰를 남긴 날짜
        'diner_open_time',      # 가게 오픈시간
        'diner_url',            # 가게 URL
        'diner_lon',            # 가게 위도
        'diner_lat'            # 가게 경도
       ]
# 사업장명, 주소, 음식종류1,음식종류2(메뉴),리뷰수,별점,리뷰
df = pd.DataFrame(columns=columns)

for i, page_url in enumerate(page_urls):
    print(f"{i}번째, {page_url}")
    # 상세보기 페이지에 접속합니다
    driver.get(page_url)
    wait = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, 'kakaoWrap')))
    # sleep(3)


    if driver.find_elements(
        By.XPATH, '//div[@class="box_grade_off"]'
    ):  # 후기를 제공하지 않는 맛집 넘기기
        continue
    
    # 사업장명
    name = driver.find_element(By.XPATH, '//h2[@class="tit_location"]').get_attribute('innerText')

    # 사업장 주소
    address = driver.find_element(By.XPATH, '//span[@class="txt_address"]').get_attribute('innerText')

    # 평균 별점
    score_min = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]/span[1]'
    ).text

    # 리뷰수
    review_num = driver.find_element(By.XPATH, '//span[@class="color_g"]').text[1:-2]
    
    #영업시간
    open_times = driver.find_elements(By.XPATH, '//ul[@class="list_operation"]')
    if len(open_times):
        open_time = open_times[0].get_attribute('innerText').split('\n')[0]
    else:
        open_time = '제공하지 않음'

    # 블로그리뷰수
    blog_review_num = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[2]/span'
    ).text

    # 음식 종류
    cat1 = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]'
    ).text

    # 메뉴
    menus = driver.find_elements(By.CLASS_NAME, "info_menu")
    cat2  = [menu.text for menu in menus]


    # 식당 장점
    likePoints = driver.find_elements(By.XPATH, '//*[@class="txt_likepoint"]')
    likePointCnts = driver.find_elements(By.XPATH, '//*[@class="num_likepoint"]')
    likePoint, likePointCnt = "", ""
    for p, c in zip(likePoints, likePointCnts):
        likePoint += p.text + "@"
        likePointCnt += c.text + "@"

    if driver.find_elements(By.XPATH, '//*[@id="mArticle"]/div[7]/div[3]/a/span[1]'):
        # 리뷰 더보기 최대로
        while not bool(
            driver.find_elements(By.XPATH, '//a[@class="link_more link_unfold"]')
        ):
            tmp_clk = driver.find_elements(By.XPATH, '//*[@class="txt_more"]')
            wait = WebDriverWait(driver, 1)
            element = wait.until(
                EC.element_to_be_clickable((By.CLASS_NAME, "link_more"))
            )
            try:
                if tmp_clk[0].text == "후기 더보기":
                    tmp_clk[0].click()
            except Exception as e:
                print("클릭 예외가 발생되었습니다.")
                pass

    try:
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")
        contents_div = soup.find(name="div", attrs={"class": "evaluation_review"})

        # 별점을 가져옵니다.
        rateNcnt = contents_div.find_all(name="span", attrs={"class": "txt_desc"})
        rateCnts = rateNcnt[::2]
        rates = rateNcnt[1::2]

        # 개인이 해당 식당에 남긴 별점
        rateAts = driver.find_elements(
            By.XPATH, '//div[@class="grade_star size_s"]/span/span'
        )

        # 리뷰를 가져옵니다.
        reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"})

        # 리뷰를 쓴 날짜를 가져옵니다.
        reviews_dates = contents_div.find_all(
            name="span", attrs={"class": "time_write"}
        )

        # 리뷰 아이디 가져오기
        reviews_ids = contents_div.find_all(name="a", attrs={"class": "link_user"})
        print("rateAts", len(rateAts), "reviews", len(reviews))
        # 데이터프레임으로 정리합니다.
        for rate, rateCnt, rateAt, review, reviews_date, reviews_id in zip(
            rates, rateCnts, rateAts, reviews, reviews_dates, reviews_ids
        ):
            rateAt = int(rateAt.get_attribute("style")[7:-2]) / 20
            row = [
                name,
                address,
                cat1,
                cat2,
                review_num,
                score_min,
                likePoint,
                rate.text,
                rateCnt.text,
                rateAt,
                reviews_date.text,
                review.find(name="span").text,
                reviews_id.text,
                open_time,
            ]

        
            series = pd.DataFrame([row], columns=columns)
            series['url'] = page_url
            # series['url'] = url
            df = pd.concat([df, series])
    except Exception as e:
        print("예외가 발생되었습니다.", e)
df = df.drop_duplicates(subset=["review", "reviewer_id", "reviews_date"], keep="first")
driver.close()

cat = {
    "베이커리,카페": [
        "폴바셋",
        "파리크라상",
        "파리바게뜨",
        "투썸플레이스",
        "커피전문점",
        "커피빈",
        "카페마마스",
        "카페",
        "제과,베이커리",
        "던킨",
        "도넛",
        "디저트카페",
        "북카페",
        "스타벅스",
    ],
    "패스트푸드": ["KFC", "햄버거", "피자", "치킨", "노브랜드버거", "맥도날드", "버거킹"],
    "육류": [
        "하남돼지집",
        "곱창,막창",
        "닭요리",
        "장어",
        "샤브샤브",
        "스테이크,립",
        "삼겹살",
        "양꼬치",
        "오발탄",
        "연타발",
        "육류,고기",
    ],
    "해산물": ["해물,생선", "해산물뷔페", "회", "조개", "게,대게", "굴,전복", "매운탕,해물탕", "아구", "복어"],
    "술집": ["호프,요리주점", "칵테일바", "술집", "실내포장마차"],
    "찌개,국밥": ["해장국", "추어", "찌개,전골", "감자탕", "곰탕", "국밥", "설렁탕", "이화수전통육개장"],
    "한식": ["한식", "한정식", "도시락", "돈까스,우동", "떡볶이", "불고기,두루치기", "분식", "순대", "소호정"],
    "일식": ["퓨전일식", "초밥,롤", "참치회", "장어", "일식집", "일본식주점", "일식"],
    "기타": ["퓨전요리", "족발,보쌈", "경복궁", "경성양꼬치", "뷔페", "온더보더", "인도음식", "족발,보쌈"],
    "양식": [
        "패밀리레스토랑",
        "터키음식",
        "태국음식",
        "동남아음식",
        "베트남음식",
        "아시아음식",
        "아웃백스테이크하우스",
        "양식",
        "이탈리안",
    ],
    "중식": ["중식", "중국요리"],
    "면류": ["국수", "냉면", "일본식라면"],
    "샌드위치,샐러드": ["샐러디", "써브웨이", "샌드위치"],
}


def cat_change(string):
    for k, v in list(cat.items()):
        if string in v:
            string = k
    return string


df["cat1"] = df["cat1"].apply(cat_change)
df['lon'], df['lat'] = 'None', 'None'

# 임시
matki_all = pd.concat([matki_all,df])

tmp_df = matki_all[(matki_all['lon'] == 'None') | (matki_all['lat'] == 'None') ]
tmp_list = set(matki_all['addresse'].to_list())
address_dict = {i:geocode(i,'road') for i in tqdm(tmp_list)}

def samedict(address):
    if address_dict[address]:
        return address_dict[address][0],address_dict[address][1]
    else:
        return 'None', 'None'

matki_all['lon'], matki_all['lat'] = zip(*matki_all['addresse'].progress_apply(samedict))

# matki_all = pd.read_csv("./result/matki_DB_raw.csv")
# matki_all = pd.concat([matki_all,df])
matki_all.drop_duplicates(subset=['review', 'reviewer_id'], keep='last')
matki_all.to_csv(f"./result/matki_DB_raw_tmux_{region}.csv", index=False, encoding='utf-8-sig')  # index label을 따로 저장하지 않기


del matki_all['reviewer_id']
del matki_all['review']


matki_all.to_csv(f"./result/matki_DB_tmux_{region}.csv", index=False, encoding='utf-8-sig')  # index label을 따로 저장하지 않기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 38
#      21 cols = ['diner_name',           # 가게이름
#      22         'diner_address',        # 가게 주소
#      23         'diner_category',       # 가게 카테고리
#    (...)
#      35         'diner_open_time'       # 가게 오픈시간
#      36        ]
#      37 # 사업장명, 주소, 음식종류1,음식종류2(메뉴),리뷰수,별점,리뷰
# ---> 38 df = pd.DataFrame(columns=columns)
#      40 for i, page_url in enumerate(page_urls):
#      41     print(f"{i}번째, {page_url}")
#
# NameError: name 'columns' is not defined

# %% [markdown]
# ## 상세 페이지 목록 가져오기

# %%
# 검색 결과의 페이지 소스를 가져옵니다
html = driver.page_source

# %%
search_window = soup.find("div", {"class": "query tf_keyword"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 soup = BeautifulSoup(html, "html.parser")
# ----> 2 search_window = soup.find("div", {"class": "query tf_keyword"}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
class=""

# %%
# 검색창에 검색어를 입력합니다
searchbox = soup.find_element(By.XPATH, "//input[@id='search.keyword.query']")
searchbox.send_keys("{0} 맛집".format(region))

# 검색버튼을 눌러서 결과를 가져옵니다
searchbutton = soup.find_element(By.XPATH, "//button[@id='search.keyword.submit']")
soup.execute_script("arguments[0].click();", searchbutton)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 검색창에 검색어를 입력합니다
# ----> 2 searchbox = soup.find_element(By.XPATH, "//input[@id='search.keyword.query']")
#       3 searchbox.send_keys("{0} 맛집".format(region))
#       5 # 검색버튼을 눌러서 결과를 가져옵니다
#
# TypeError: 'NoneType' object is not callable

# %%
tqdm.pandas()
##############################################################  ############
##################### variable related geo ##########################
##########################################################################
def get_coordinates(address):
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None, None




##############################################################  ############
##################### variable related selenium ##########################
##########################################################################

geolocator = Nominatim(user_agent="geoapiExercises")
matki_all = pd.read_csv("./matki_DB_raw.csv")


source_url = "https://map.kakao.com/"
# , "망원", "삼성", "삼성중앙", "선정릉", "신논현", "광흥창", "신촌", "양재", "역삼", "종로3가", "을지로3가", "영등포구청", "문래", "당산"
region = "마포구청"+"역"
# 합정, 망원, 삼성, 삼성중앙, 선정릉, 신논현, 당산, 홍대입구, 역삼역, 광흥창, 신촌
print(f'{region}을 시작합니다.')
# 크롬 드라이버를 사용합니다 (맥은 첫 줄, 윈도우는 두번째 줄 실행)


# 카카오 지도에 접속합니다
driver.get(source_url)
# 검색창에 검색어를 입력합니다
searchbox = driver.find_element(By.XPATH, "//input[@id='search.keyword.query']")
searchbox.send_keys("{0} 맛집".format(region))

# 검색버튼을 눌러서 결과를 가져옵니다
searchbutton = driver.find_element(By.XPATH, "//button[@id='search.keyword.submit']")
driver.execute_script("arguments[0].click();", searchbutton)

# 검색 결과를 가져올 시간을 기다립니다
sleep(2)




driver.find_element(By.XPATH, "/html/body/div[10]/div/div/div/span").click()
sleep(2)
# 더보기 클릭
driver.find_element(By.XPATH, "//*[@id='info.search.place.more']").click()
sleep(2)
# 1~ 5페이지 링크 얻기
page_urls = []
cnt = 0
while driver.find_element(By.XPATH, '//a[@id="info.search.page.no5"]').is_displayed():
    for i in range(1, 6):
        page = driver.find_element(By.ID, "info.search.page.no" + str(i))
        page.click()
        sleep(2)
        urls = driver.find_elements(By.LINK_TEXT, "상세보기")
        for j in range(len(urls)):
            url = urls[j].get_attribute("href")
            print(url)
            page_urls.append(url)
    if (not bool(10 % 5)) & (
        not bool(driver.find_elements(By.XPATH, '//button[@class="next disabled"]'))
    ):
        driver.find_elements(By.XPATH, '//button[@id="info.search.page.next"]')[
            0
        ].click()


columns = [
    "region",
    "name",
    "addresse",
    "cat1",
    "cat2",
    "review_num",
    "blog_review_num",
    "open_time",
    "score_min",
    "likePoint",
    "likePointCnt",
    "rate",
    "reviewerCnt",
    "reviewAt",
    "review",
    "reviews_date",
    "reviewer_id"
]
# 사업장명, 주소, 음식종류1,음식종류2(메뉴),리뷰수,별점,리뷰
df = pd.DataFrame(columns=columns)

for i, page_url in enumerate(page_urls):
    print(f"{i}번째, {page_url}")
    # 상세보기 페이지에 접속합니다
    driver.get(page_url)
    wait = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.ID, 'kakaoWrap')))
    sleep(3)


    if driver.find_elements(
        By.XPATH, '//div[@class="box_grade_off"]'
    ):  # 후기를 제공하지 않는 맛집 넘기기
        continue
    
    # 사업장명
    name = driver.find_element(By.XPATH, '//h2[@class="tit_location"]').get_attribute('innerText')

    # 사업장 주소
    address = driver.find_element(By.XPATH, '//span[@class="txt_address"]').get_attribute('innerText')

    # 평균 별점
    score_min = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[1]/span[1]'
    ).text

    # 리뷰수
    review_num = driver.find_element(By.XPATH, '//span[@class="color_g"]').text[1:-2]
    
    #영업시간
    open_times = driver.find_elements(By.XPATH, '//ul[@class="list_operation"]')
    if len(open_times):
        open_time = open_times[0].get_attribute('innerText').split('\n')[0]
    else:
        open_time = '제공하지 않음'
    # 블로그리뷰수
    blog_review_num = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/a[2]/span'
    ).text

    # 음식 종류
    cat1 = driver.find_element(
        By.XPATH, '//*[@id="mArticle"]/div[1]/div[1]/div[2]/div/div/span[1]'
    ).text

    # 메뉴
    cat2 = []

    menus = driver.find_elements(By.CLASS_NAME, "info_menu")
    for menu in menus:
        cat2.append(menu.text)

    # 식당 장점
    likePoints = driver.find_elements(By.XPATH, '//*[@class="txt_likepoint"]')
    likePointCnts = driver.find_elements(By.XPATH, '//*[@class="num_likepoint"]')
    likePoint, likePointCnt = "", ""
    for p, c in zip(likePoints, likePointCnts):
        likePoint += p.text + "@"
        likePointCnt += c.text + "@"

    if driver.find_elements(By.XPATH, '//*[@id="mArticle"]/div[7]/div[3]/a/span[1]'):
        # 리뷰 더보기 최대로
        while not bool(
            driver.find_elements(By.XPATH, '//a[@class="link_more link_unfold"]')
        ):
            tmp_clk = driver.find_elements(By.XPATH, '//*[@class="txt_more"]')
            wait = WebDriverWait(driver, 1)
            element = wait.until(
                EC.element_to_be_clickable((By.CLASS_NAME, "link_more"))
            )
            try:
                if tmp_clk[0].text == "후기 더보기":
                    tmp_clk[0].click()
            except Exception as e:
                print("클릭 예외가 발생되었습니다.")
                pass

    try:
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")
        contents_div = soup.find(name="div", attrs={"class": "evaluation_review"})

        # 별점을 가져옵니다.
        rateNcnt = contents_div.find_all(name="span", attrs={"class": "txt_desc"})
        rateCnts = rateNcnt[::2]
        rates = rateNcnt[1::2]

        # 개인이 해당 식당에 남긴 별점
        rateAts = driver.find_elements(
            By.XPATH, '//div[@class="grade_star size_s"]/span/span'
        )

        # 리뷰를 가져옵니다.
        reviews = contents_div.find_all(name="p", attrs={"class": "txt_comment"})

        # 리뷰를 쓴 날짜를 가져옵니다.
        reviews_dates = contents_div.find_all(
            name="span", attrs={"class": "time_write"}
        )

        # 리뷰 아이디 가져오기
        reviews_ids = contents_div.find_all(name="a", attrs={"class": "link_user"})
        print("rateAts", len(rateAts), "reviews", len(reviews))
        # 데이터프레임으로 정리합니다.
        for rate, rateCnt, rateAt, review, reviews_date, reviews_id in zip(
            rates, rateCnts, rateAts, reviews, reviews_dates, reviews_ids
        ):
            rateAt = int(rateAt.get_attribute("style")[7:-2]) / 20
            row = [
                region,
                name,
                address,
                cat1,
                cat2,
                review_num,
                blog_review_num,
                open_time,
                score_min,
                likePoint,
                likePointCnt,
                rate.text,
                rateCnt.text,
                rateAt,
                review.find(name="span").text,
                reviews_date.text,
                reviews_id.text,
            ]
            series = pd.DataFrame([row], columns=columns)
            series['url'] = page_url
            # series['url'] = url
            df = pd.concat([df, series])
    except Exception as e:
        print("예외가 발생되었습니다.", e)
df = df.drop_duplicates(subset=["review", "reviewer_id", "reviews_date"], keep="first")
driver.close()

cat = {
    "베이커리,카페": [
        "폴바셋",
        "파리크라상",
        "파리바게뜨",
        "투썸플레이스",
        "커피전문점",
        "커피빈",
        "카페마마스",
        "카페",
        "제과,베이커리",
        "던킨",
        "도넛",
        "디저트카페",
        "북카페",
        "스타벅스",
    ],
    "패스트푸드": ["KFC", "햄버거", "피자", "치킨", "노브랜드버거", "맥도날드", "버거킹"],
    "육류": [
        "하남돼지집",
        "곱창,막창",
        "닭요리",
        "장어",
        "샤브샤브",
        "스테이크,립",
        "삼겹살",
        "양꼬치",
        "오발탄",
        "연타발",
        "육류,고기",
    ],
    "해산물": ["해물,생선", "해산물뷔페", "회", "조개", "게,대게", "굴,전복", "매운탕,해물탕", "아구", "복어"],
    "술집": ["호프,요리주점", "칵테일바", "술집", "실내포장마차"],
    "찌개,국밥": ["해장국", "추어", "찌개,전골", "감자탕", "곰탕", "국밥", "설렁탕", "이화수전통육개장"],
    "한식": ["한식", "한정식", "도시락", "돈까스,우동", "떡볶이", "불고기,두루치기", "분식", "순대", "소호정"],
    "일식": ["퓨전일식", "초밥,롤", "참치회", "장어", "일식집", "일본식주점", "일식"],
    "기타": ["퓨전요리", "족발,보쌈", "경복궁", "경성양꼬치", "뷔페", "온더보더", "인도음식", "족발,보쌈"],
    "양식": [
        "패밀리레스토랑",
        "터키음식",
        "태국음식",
        "동남아음식",
        "베트남음식",
        "아시아음식",
        "아웃백스테이크하우스",
        "양식",
        "이탈리안",
    ],
    "중식": ["중식", "중국요리"],
    "면류": ["국수", "냉면", "일본식라면"],
    "샌드위치,샐러드": ["샐러디", "써브웨이", "샌드위치"],
}


def cat_change(string):
    for k, v in list(cat.items()):
        if string in v:
            string = k
    return string


df["cat1"] = df["cat1"].apply(cat_change)
df['lon'], df['lat'] = 'None', 'None'

# 임시
matki_all = pd.concat([matki_all,df])

tmp_df = matki_all[(matki_all['lon'] == 'None') | (matki_all['lat'] == 'None') ]
tmp_list = set(matki_all['addresse'].to_list())
address_dict = {i:geocode(i,'road') for i in tqdm(tmp_list)}

def samedict(address):
    if address_dict[address]:
        return address_dict[address][0],address_dict[address][1]
    else:
        return 'None', 'None'

matki_all['lon'], matki_all['lat'] = zip(*matki_all['addresse'].progress_apply(samedict))

# matki_all = pd.read_csv("./result/matki_DB_raw.csv")
# matki_all = pd.concat([matki_all,df])
matki_all.drop_duplicates(subset=['review', 'reviewer_id'], keep='last')
matki_all.to_csv(f"./result/matki_DB_raw_tmux_{region}.csv", index=False, encoding='utf-8-sig')  # index label을 따로 저장하지 않기


del matki_all['reviewer_id']
del matki_all['review']


matki_all.to_csv(f"./result/matki_DB_tmux_{region}.csv", index=False, encoding='utf-8-sig')  # index label을 따로 저장하지 않기
